# %% [markdown]
# # 🔹 1️⃣ Data Types in Python
# ### 🔸 Integer (int)

# %%
a = 10
b = -5
print(a, b)
# Out:
# 10 -5

# %% [markdown]
# ### 🔸 Float (float)

# %%
pi = 7.23
price = 99.99
print(pi, price)
# Out:
# 7.23 99.99

# %% [markdown]
# ### 🔸 String (str)
# Text data (inside quotes)

# %%
name = "Sayali"
city = "Pune"
print(name, city)
# Out:
# Sayali Pune

# %% [markdown]
# ### 🔸 Boolean (bool)
#
# True or False

# %%
is_python_easy = True
is_rainy_weather = False
print(is_python_easy, is_rainy_weather)
# Out:
# True False

# %% [markdown]
# # 🔹 2️⃣ Check Data Type

# %%
x = 20
print(type(x))

y = "abc"
print(type(y))
# Out:
# <class 'int'>
# <class 'str'>

# %% [markdown]
# # 🔹 3️⃣ Type Conversion (Very Important ⭐)
# ### 🔸 String to Integer

# %%
age = input("Your Age :")
age = int(age)
print(age)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[10], line 2
#       1 age = input("Your Age :")
# ----> 2 age = int(age)
#       3 print(age)
#
# ValueError: invalid literal for int() with base 10: 'jgjj'

# %% [markdown]
# ### 🔸 Integer to String

# %%
num = 25
print("My number is :" +str(num))
# Out:
# My number is :25

# %% [markdown]
# ### 🔸 Float Conversion

# %%
x = int(3.9)
print(x)
# Out:
# 3

# %% [markdown]
# ⚠️ Common Beginner Mistake

# %%
# ❌ This gives error:
age = input("Enter age: ")
print(age + 5)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[20], line 2
#       1 age = input("Enter age: ")
# ----> 2 print(age + 5)
#
# TypeError: can only concatenate str (not "int") to str

# %%
# ✅ Correct way:
age = int(input("Enter age:"))
print(age + 5)
# Out:
# 30

# %% [markdown]
# 📝 Practice Tasks (IMPORTANT)
#
# 1️⃣ Take two numbers from user and print their sum

# %%
a = int(input("Enter any number:"))
b = int(input("Enter another number:"))

# print("Sum is:",a + b) or

sum = a + b
print(sum)
# Out:
# 8

# %% [markdown]
# 2️⃣ Take name and age, print a sentence

# %%
name = input("Your Name:")
age = input("Your Age:")
print("My name is ", name ,"and I am ", age ,"years old")
# Out:
# My name is  abc and I am  20 years old

# %% [markdown]
# 3️⃣ Check type of each variable

# %%
name = "abc"
age = 25
height = 5.2
is_student =True
print(type(name))
print(type(age))
print(type(height))
print(type(is_student))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'float'>
# <class 'bool'>

# %% [markdown]
# 4️⃣ Take two numbers and print their product

# %%
num1 = int(input("Enter num 1:"))
num2 = int(input("Enter num 2:"))
product = num1 * num2
print("Product is:",product)
# Out:
# Product is: 200
