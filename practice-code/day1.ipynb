# %% [markdown]
# # ✅ Your First Python Program

# %%
print("Hello")
# Out:
# Hello

# %% [markdown]
# ## ✅ Variables (Very Important)

# %%
name = "Sayali"
age = 25
is_student = True

print(name)
print("Age :",age)
print("Is Student :",is_student)
# Out:
# Sayali
# Age : 25
# Is Student : True

# %% [markdown]
# ## ✅ Input from User

# %%
name = input("Enyer Your Name:")   
print("Hello",name)
# Out:
# Hello abc

# %% [markdown]
# ## 📝 Practice (DO THIS NOW 👇)
#
# 1️⃣ Print your name, age, and city

# %%
name = input("Enter your Name :")
age = 25
city = "Klohapur"

print(name)
print(age)
print(city)
# Out:
# sayali
# 25
# Klohapur

# %%
name = input("Enter your Name :")
age = 25
city = input("Enter City :")
print("Name :",name)
print("Age :",age)
print("City :",city)
# Out:
# Name : xyz
# Age : 25
# City : abc

# %% [markdown]
# 2️⃣ Take name as input and greet user

# %%
name = input("Your Name:")
print("Hello",name)
# Out:
# Hello sam

# %% [markdown]
# 3️⃣ Try changing values and re-run

# %%
name = "Ishita"
age = 22
print(name)
print(age)
# Out:
# Ishita
# 22
