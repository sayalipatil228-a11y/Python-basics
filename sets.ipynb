# %% [markdown]
# # Python Sets
# Sets are unordered collection of data items. They store multiple items in a single variable. Set items are separated by commas and enclosed within curly brackets {}. Sets are unchangeable, meaning you cannot change items of the set once created. Sets do not contain duplicate items.

# %%
s = {2, 4, 67, 2, 23} 
print(s)
# Out:
# {2, 67, 4, 23}

# %%
info = {'sab', 2, 54, False, 5, 9.9}
print(info)
# Out:
# {False, 2, 'sab', 5, 54, 9.9}

# %%
saya = {} # this is not empty set
print(type(saya))

sana = set() # empty set 
print(type(sana))
# Out:
# <class 'dict'>
# <class 'set'>

# %%
info = {'sab', 2, 54, False, 5, 9.9}
for value in info:
    print(value)
# Out:
# False
# 2
# sab
# 5
# 54
# 9.9

# %% [markdown]
# # Joining Sets
# ### I. union() and update():
# The union() and update() methods prints all items that are present in the two sets. The union() method returns a new set whereas update() method adds item into the existing set from another set.

# %%
cities = {"kolhapur", "pune", "kolkata", "bengulure", "delhi"}
cities2 = {"mumbai", "gujarat", "karnataka", "haidrabad", "kolhapur"}
cities3 = cities.union(cities2)
print(cities3)
# Out:
# {'gujarat', 'delhi', 'bengulure', 'kolkata', 'karnataka', 'mumbai', 'haidrabad', 'pune', 'kolhapur'}

# %%
cities = {"kolhapur", "pune", "kolkata", "bengulure", "delhi"}
cities2 = {"mumbai", "gujarat", "karnataka", "haidrabad", "kolhapur"}
cities.update(cities2)
print(cities)
# Out:
# {'gujarat', 'delhi', 'bengulure', 'kolkata', 'karnataka', 'mumbai', 'haidrabad', 'pune', 'kolhapur'}

# %% [markdown]
# ### II. intersection and intersection_update():
# The intersection() and intersection_update() methods prints only items that are similar to both the sets. The intersection() method returns a new set whereas intersection_update() method updates into the existing set from another set.

# %%
cities = {"kolhapur", "pune", "kolkata", "bengulure", "delhi"}
cities2 = {"mumbai", "gujarat", "karnataka", "haidrabad", "kolhapur"}
cities3 = cities.intersection(cities2)
print(cities3)
# Out:
# {'kolhapur'}

# %%
cities = {"kolhapur", "pune", "kolkata", "bengulure", "delhi"}
cities2 = {"mumbai", "gujarat", "karnataka", "haidrabad", "kolhapur"}
cities.intersection_update(cities2)
print(cities)
# Out:
# {'kolhapur'}

# %% [markdown]
# ### III. symmetric_difference and symmetric_difference_update():
# The symmetric_difference() and symmetric_difference_update() methods prints only items that are not similar to both the sets. The symmetric_difference() method returns a new set whereas symmetric_difference_update() method updates into the existing set from another set.

# %%
cities = {"kolhapur", "pune", "kolkata", "bengulure", "delhi"}
cities2 = {"mumbai", "gujarat", "karnataka", "haidrabad", "kolhapur", "pune"}
cities3 = cities.symmetric_difference(cities2)
print(cities3)
# Out:
# {'gujarat', 'kolkata', 'karnataka', 'mumbai', 'haidrabad', 'delhi', 'bengulure'}

# %%
cities = {"kolhapur", "pune", "kolkata", "bengulure", "delhi"}
cities2 = {"mumbai", "gujarat", "karnataka", "haidrabad", "kolhapur", "pune"}
cities.symmetric_difference_update(cities2)
print(cities)
# Out:
# {'gujarat', 'delhi', 'bengulure', 'karnataka', 'kolkata', 'mumbai', 'haidrabad'}

# %% [markdown]
# ### IV. difference() and difference_update():
# The difference() and difference_update() methods prints only items that are only present in the original set and not in both the sets. The difference() method returns a new set whereas difference_update() method updates into the existing set from another set.

# %%
cities = {"kolhapur", "pune", "kolkata", "bengulure", "delhi"}
cities2 = {"Seoul", "Kabul", "Delhi"}
cities3 = cities.difference(cities2)
print(cities3)
# Out:
# {'delhi', 'bengulure', 'kolkata', 'pune', 'kolhapur'}

# %%
cities = {"kolhapur", "pune", "kolkata", "bengulure", "delhi"}
cities2 = {"Seoul", "Kabul", "Delhi"}
cities.difference_update(cities2)
print(cities)
# Out:
# {'delhi', 'bengulure', 'pune', 'kolkata', 'kolhapur'}
